# %%
#Q.1 Data visualisation and statistical measure
import numpy as np
import sympy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("iris (1).csv")
dataset
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
#Histogram
sns.histplot(dataset['Sepal.Width'],kde=True,bins=10, color='g')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sepal.Width', ylabel='Count'>

# %%
sns.histplot(dataset['Petal.Width'],kde=True,bins=10, color='g')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Petal.Width', ylabel='Count'>

# %%
sns.histplot(dataset['Sepal.Length'],kde=True,bins=10, color='b')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sepal.Length', ylabel='Count'>

# %%
sns.histplot(dataset['Petal.Length'],kde=True,bins=10, color='b')
# Out:
# C:\Users\goo dy\anaconda3\conda-meta\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Petal.Length', ylabel='Count'>

# %%
plt.scatter(dataset['Sepal.Length'],dataset['Sepal.Width'],color='g')

# %%
plt.scatter(dataset['Petal.Length'],dataset['Petal.Width'],color='orange')

# %%
plt.scatter(dataset['Sepal.Length'],dataset['Sepal.Width'],dataset['Petal.Length'],dataset['Petal.Width'],marker='x')

# %%
sns.boxplot(x='Sepal.Width',data=dataset,color='orange')
# Out:
# <Axes: xlabel='Sepal.Width'>

# %%
sns.boxplot(x='Sepal.Width',data=dataset,color='orange')
# Out:
# <Axes: ylabel='Sepal.Length'>

# %%
sns.boxplot(x='Petal.Length',data=dataset,color='g')
# Out:
# <Axes: xlabel='Petal.Length'>

# %%
sns.boxplot(x='Petal.Width',data=dataset,color='orange')
# Out:
# <Axes: xlabel='Petal.Width'>

# %%
#plot subplot 
plt.subplot(331)
plt.scatter(dataset['Petal.Length'],dataset['Petal.Width'],c='orange')
plt.subplot(332)
plt.scatter(dataset['Sepal.Length'],dataset['Sepal.Width'],c='red')
plt.subplot(333)
plt.scatter(dataset['Sepal.Length'],dataset['Petal.Width'],c='green')
plt.subplot(334)
plt.scatter(dataset['Petal.Length'],dataset['Sepal.Width'],c='violet')

# %%
mean1= dataset['Sepal.Width'].mean()
mean1
# Out:
# 3.0573333333333337

# %%
mean2= dataset['Sepal.Length'].mean()
mean2
# Out:
# 5.843333333333334

# %%
mean3= dataset['Petal.Width'].mean()
mean3
# Out:
# 1.1993333333333336

# %%
mean4= dataset['Petal.Length'].mean()
mean4
# Out:
# 3.7580000000000005

# %%
median1= dataset['Sepal.Width'].median()
median1
# Out:
# 3.0

# %%
median2= dataset['Sepal.Length'].median()
median2
# Out:
# 5.8

# %%
median3= dataset['Petal.Width'].median()
median3
# Out:
# 1.3

# %%
median4= dataset['Petal.Length'].median()
median4
# Out:
# 4.35

# %%
mode1= dataset['Sepal.Width'].mode()
mode1
# Out:
# 0    3.0
# Name: Sepal.Width, dtype: float64

# %%
mode2= dataset['Sepal.Length'].mode()
mode2
# Out:
# 0    5.0
# Name: Sepal.Length, dtype: float64

# %%
mode3= dataset['Petal.Width'].mode()
mode3
# Out:
# 0    0.2
# Name: Petal.Width, dtype: float64

# %%
mode4= dataset['Petal.Length'].mode()
mode4
# Out:
# 0    1.4
# 1    1.5
# Name: Petal.Length, dtype: float64

# %%
SD1= dataset['Sepal.Width'].std()
SD1
# Out:
# 0.435866284936698

# %%
SD2= dataset['Sepal.Length'].std()
SD2
# Out:
# 0.8280661279778629

# %%
SD3= dataset['Petal.Width'].std()
SD3
# Out:
# 0.7622376689603465

# %%
SD4= dataset['Petal.Length'].std()
SD4
# Out:
# 1.7652982332594667

# %%
dataset.describe()
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
